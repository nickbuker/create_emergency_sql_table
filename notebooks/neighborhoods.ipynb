# %%
from __future__ import division
import pandas as pd
import numpy as np
from matplotlib.patches import Polygon
import matplotlib
from matplotlib.collections import PatchCollection
from mpl_toolkits.basemap import Basemap
from shapely.geometry import Point, Polygon, MultiPoint, MultiPolygon
from shapely.prepared import prep
from descartes import PolygonPatch
import matplotlib.pyplot as plt
from collections import defaultdict

% matplotlib inline

# %%
# Create a Dataframe and drop extra column
df = pd.read_csv('../data/features_seattle_911_no_dup_seasonalilty.csv', low_memory=False)
df.drop(['Unnamed: 0'], axis=1, inplace=True)
df.Datetime = pd.to_datetime(df.Datetime)

# %%
df.head()
# Out:
#                    Address                     Type            Datetime  \
# 0           6900 37th Av S           Medic Response 2011-11-09 23:33:00
# 1  N 50th St / Stone Way N             Aid Response 2011-11-09 23:32:00
# 2  E John St / E Olive Way             Aid Response 2011-11-09 23:32:00
# 3            611 12th Av S             Aid Response 2011-11-09 23:29:00
# 4          4545 42nd Av Sw  Automatic Medical Alarm 2011-11-09 23:25:00
#
#     Latitude   Longitude           Report Location Incident Number  \
# 0  47.540683 -122.286131  (47.540683, -122.286131)      F110104166
# 1  47.665034 -122.340207  (47.665034, -122.340207)      F110104164
# 2  47.619575 -122.324257  (47.619575, -122.324257)      F110104165
# 3  47.597406 -122.317228  (47.597406, -122.317228)      F110104162
# 4  47.562472 -122.385455  (47.562472, -122.385455)      F110104161
#
#                   dt_crop        date      time     ...         weekday night  \
# 0  11/09/2011 11:33:00 PM  2011-11-09  23:33:00     ...       Wednesday     1
# 1  11/09/2011 11:32:00 PM  2011-11-09  23:32:00     ...       Wednesday     1
# 2  11/09/2011 11:32:00 PM  2011-11-09  23:32:00     ...       Wednesday     1
# 3  11/09/2011 11:29:00 PM  2011-11-09  23:29:00     ...       Wednesday     1
# 4  11/09/2011 11:25:00 PM  2011-11-09  23:25:00     ...       Wednesday     1
#
#    Monday  Saturday  Sunday  Thursday  Tuesday Wednesday  day_num  seasonality
# 0       0         0       0         0        0         1      498     0.889486
# 1       0         0       0         0        0         1      498     0.889486
# 2       0         0       0         0        0         1      498     0.889486
# 3       0         0       0         0        0         1      498     0.889486
# 4       0         0       0         0        0         1      498     0.889486
#
# [5 rows x 27 columns]

# %%
def plot_prepper(m, shapefilename, df_key):
    '''
    Generate dataframe for plotting
    '''
    _out = m.readshapefile(shapefilename, name='seattle', drawbounds=False, color='none', zorder=2)
    # set up a map dataframe for neighborhood outlines
    cent_lons = [float((Polygon(points).centroid.wkt).split()[1][1:]) for points in m.seattle]
    cent_lats = [float((Polygon(points).centroid.wkt).strip(')').split()[2]) for points in m.seattle]

    df_poly = pd.DataFrame({
        'poly': [Polygon(points) for points in m.seattle],
        'name': [item[df_key] for item in m.seattle_info],
    })
    df_poly['centroid_1'] = cent_lons
    df_poly['centroid_2'] = cent_lats
    return _out, df_poly

# Read in neighborhood shape file
hood_shapefilename = '../neighborhoods_shape/WGS84/Neighborhoods'
hood_coords = (-122.43595589761988, 47.49551362397606, 
               -122.23604445458412, 47.73416494684497)

w, h = hood_coords[2] - hood_coords[0], hood_coords[3] - hood_coords[1]
extra = 0.005

# Initialize the plot
figwidth = 12
fig = plt.figure(figsize=(figwidth, figwidth*h/w))
ax = fig.add_subplot(111, axisbg='w', frame_on=False)
m = Basemap(projection='tmerc', ellps='WGS84',
            lon_0=np.mean([hood_coords[0], hood_coords[2]]),
            lat_0=np.mean([hood_coords[1], hood_coords[3]]),
            llcrnrlon=hood_coords[0] - extra * w,
            llcrnrlat=hood_coords[1] - (extra * h),
            urcrnrlon=hood_coords[2] + extra * w,
            urcrnrlat=hood_coords[3] + (extra * h),
            resolution='i',  suppress_ticks=True)

# Get dataframe for plotting
_out, df_map = plot_prepper(m, hood_shapefilename, 'S_HOOD')
nbr_names = df_map['name'].unique()

# Draw neighborhoods with grey outlines
df_map['patches'] = df_map['poly'].map(lambda x: PolygonPatch(x, ec='#050505', lw=.8, alpha=1., zorder=4))
pc = PatchCollection(df_map['patches'], match_original=True)
pc.set_facecolor('w')
ax.add_collection(pc)

# Scale the map
m.drawmapscale(hood_coords[0] + 0.08, hood_coords[1] + -0.01, 
               hood_coords[0], hood_coords[1], 10., barstyle='fancy',
               fillcolor1='w', fillcolor2='#555555', zorder=5, ax=ax,)

lons = df.Longitude
lats = df.Latitude

pt = []
xs = []
ys = []

'''
This plots all the latitude/longitude points
'''
for mapped_x, mapped_y in zip(lons, lats):
    xpt, ypt = m(mapped_x, mapped_y)
    plt.plot(xpt, ypt, '.', markersize=5, alpha=0.03, color='r')
    pt.append(Point(xpt, ypt))
    xs.append(xpt)
    ys.append(ypt)

Labels = []
nmlist = []

'''
Checks the neighborhood of point
'''
# Creates list of neighborhoods
for polygon in df_map['poly']:
    nm = df_map.loc[df_map['poly'] == polygon, 'name'].iloc[0]
    if len(nm.strip()) < 4 or nm in nmlist:
        continue
    nmlist.append(nm)

"""
Determines neighborhood of point
"""
for i, p in enumerate(pt):
    # Create Unknown placeholder to capture points no in a neighborhood
    Labels.append('Unknown')
    # Tracks progress
    if i % 50000 == 0:
        print i
    # Creates polygon and if pt in polygon records neighborhood name
    for j, row in df_map.iterrows():
        polygon = row['poly']
        nm = row[0]
        if polygon.contains(p):
            Labels[i] = nm

# Add neighborhood names
nml = []
for i, lon in enumerate(df_map['centroid_1'].values):
    if df_map['name'].values[i] in nml:
        continue
    nml.append(df_map['name'].values[i])
    if len(df_map['name'].values[i]) > 3:
        plt.text(lon, df_map['centroid_2'].values[i], df_map['name'].values[i], size=7, ha='center')

ax.axes.get_xaxis().set_visible(False)
#plt.savefig('../images/seattle_911_neighborhoods.png')
# Out:
# 0
# 50000
# 100000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-848696a431f1> in <module>()
#      92         print i
#      93     # Creates polygon and if pt in polygon records neighborhood name
# ---> 94     for j, row in df_map.iterrows():
#      95         polygon = row['poly']
#      96         nm = row[0]
#
# /home/nick/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in iterrows(self)
#     654         columns = self.columns
#     655         for k, v in zip(self.index, self.values):
# --> 656             s = Series(v, index=columns, name=k)
#     657             yield k, s
#     658
#
# /home/nick/anaconda2/lib/python2.7/site-packages/pandas/core/series.pyc in __init__(self, data, index, dtype, name, copy, fastpath)
#     229                 data = SingleBlockManager(data, index, fastpath=True)
#     230
# --> 231         generic.NDFrame.__init__(self, data, fastpath=True)
#     232
#     233         self.name = name
#
# /home/nick/anaconda2/lib/python2.7/site-packages/pandas/core/generic.pyc in __init__(self, data, axes, copy, dtype, fastpath)
#      92     is_copy = None
#      93
# ---> 94     def __init__(self, data, axes=None, copy=False, dtype=None,
#      95                  fastpath=False):
#      96
#
# KeyboardInterrupt:

# %%
if 'Unknown' in Labels:
    print 'yes'
if 'Unknown' not in Labels:
    print 'no'
# Out:
# yes

# %%
len(Labels)
# Out:
# 551095

# %%
len(df)
# Out:
# 551095

# %%
len(nmlist)
# Out:
# 90

# %%
len(df_map)
# Out:
# 121

# %%
Labels
# Out:
# ['Holly Park',
#  'Wallingford',
#  'Broadway',
#  'International District',
#  'Genesee',
#  'Belltown',
#  'Brighton',
#  'South Delridge',
#  'Ravenna',
#  'University District',
#  'East Queen Anne',
#  'Haller Lake',
#  'Belltown',
#  'Pinehurst',
#  'Roxhill',
#  'Pike-Market',
#  'Minor',
#  'Yesler Terrace',
#  'Lower Queen Anne',
#  'Greenwood',
#  'Central Business District',
#  'Central Business District',
#  'Brighton',
#  'Green Lake',
#  'Mount Baker',
#  'Fremont',
#  'Belltown',
#  'Holly Park',
#  'Belltown',
#  'South Park',
#  'Cedar Park',
#  'Lower Queen Anne',
#  'Stevens',
#  'Fairmount Park',
#  'Pioneer Square',
#  'Minor',
#  'South Park',
#  'North Admiral',
#  'Broadview',
#  'Adams',
#  'Alki',
#  'Pioneer Square',
#  'Cedar Park',
#  'Bitter Lake',
#  'Windermere',
#  'Dunlap',
#  'Pioneer Square',
#  'Rainier Beach',
#  'Bitter Lake',
#  'South Delridge',
#  'Stevens',
#  'Greenwood',
#  'South Lake Union',
#  'Phinney Ridge',
#  'Wallingford',
#  'Loyal Heights',
#  'North Queen Anne',
#  'Bitter Lake',
#  'Haller Lake',
#  'North Beacon Hill',
#  'Dunlap',
#  'Pioneer Square',
#  'International District',
#  'First Hill',
#  'Greenwood',
#  'Minor',
#  'Mid-Beacon Hill',
#  'Stevens',
#  'Pioneer Square',
#  'Rainier View',
#  'Central Business District',
#  'Central Business District',
#  'Adams',
#  'Cedar Park',
#  'High Point',
#  'Belltown',
#  'Pioneer Square',
#  'Mount Baker',
#  'Belltown',
#  'University District',
#  'International District',
#  'North Admiral',
#  'Olympic Hills',
#  'Fremont',
#  'Central Business District',
#  'Pioneer Square',
#  'Mid-Beacon Hill',
#  'Broadway',
#  'Belltown',
#  'Roosevelt',
#  'Columbia City',
#  'Fairmount Park',
#  'Mid-Beacon Hill',
#  'Holly Park',
#  'Alki',
#  'Stevens',
#  'Central Business District',
#  'West Queen Anne',
#  'Lower Queen Anne',
#  'Southeast Magnolia',
#  'High Point',
#  'Highland Park',
#  'Lower Queen Anne',
#  'Riverview',
#  'First Hill',
#  'First Hill',
#  'Ravenna',
#  'Green Lake',
#  'Leschi',
#  'North College Park',
#  'Seaview',
#  'Haller Lake',
#  'First Hill',
#  'Mann',
#  'Highland Park',
#  'Belltown',
#  'Roosevelt',
#  'Highland Park',
#  'Roxhill',
#  'Central Business District',
#  'Yesler Terrace',
#  'Minor',
#  'Madison Park',
#  'Greenwood',
#  'Brighton',
#  'University District',
#  'Minor',
#  'Loyal Heights',
#  'Rainier Beach',
#  'University District',
#  'Broadway',
#  'North Beacon Hill',
#  'Sunset Hill',
#  'Belltown',
#  'Central Business District',
#  'Pinehurst',
#  'Adams',
#  'Columbia City',
#  'Phinney Ridge',
#  'Wallingford',
#  'Industrial District',
#  'University District',
#  'First Hill',
#  'North Delridge',
#  'Central Business District',
#  'South Park',
#  'Fremont',
#  'Highland Park',
#  'West Woodland',
#  'North Beacon Hill',
#  'Adams',
#  'Mid-Beacon Hill',
#  'Pioneer Square',
#  'High Point',
#  'Wallingford',
#  'Industrial District',
#  'University District',
#  'Adams',
#  'Lower Queen Anne',
#  'Holly Park',
#  'West Woodland',
#  'Wallingford',
#  'Columbia City',
#  'University District',
#  'Brighton',
#  'Phinney Ridge',
#  'Fremont',
#  'Central Business District',
#  'First Hill',
#  'Alki',
#  'Columbia City',
#  'Victory Heights',
#  'University District',
#  'Lawton Park',
#  'Maple Leaf',
#  'Phinney Ridge',
#  'Bitter Lake',
#  'Broadway',
#  'Wallingford',
#  'University District',
#  'Lawton Park',
#  'Mount Baker',
#  'Broadway',
#  'Belltown',
#  'Greenwood',
#  'Broadway',
#  'Columbia City',
#  'Adams',
#  'Unknown',
#  'Arbor Heights',
#  'Pinehurst',
#  'Alki',
#  'First Hill',
#  'Industrial District',
#  'Lower Queen Anne',
#  'University District',
#  'Wallingford',
#  'Loyal Heights',
#  'Brighton',
#  'Columbia City',
#  'South Lake Union',
#  'Genesee',
#  'Loyal Heights',
#  'Columbia City',
#  'Broadway',
#  'Pinehurst',
#  'Columbia City',
#  'Brighton',
#  'Pike-Market',
#  'Pinehurst',
#  'Pike-Market',
#  'First Hill',
#  'First Hill',
#  'Columbia City',
#  'First Hill',
#  'Central Business District',
#  'Eastlake',
#  'Belltown',
#  'Southeast Magnolia',
#  'University District',
#  'Pike-Market',
#  'Pioneer Square',
#  'Mid-Beacon Hill',
#  'Pioneer Square',
#  'Minor',
#  'View Ridge',
#  'Mount Baker',
#  'Ravenna',
#  'Mid-Beacon Hill',
#  'Meadowbrook',
#  'Lower Queen Anne',
#  'South Lake Union',
#  'First Hill',
#  'Industrial District',
#  'Fairmount Park',
#  'Wallingford',
#  'Pinehurst',
#  'Belltown',
#  'Belltown',
#  'Yesler Terrace',
#  'North Delridge',
#  'Broadway',
#  'Highland Park',
#  'Fremont',
#  'Industrial District',
#  'Pioneer Square',
#  'Greenwood',
#  'Minor',
#  'Adams',
#  'Broadview',
#  'Cedar Park',
#  'Alki',
#  'Dunlap',
#  'Broadway',
#  'Laurelhurst',
#  'North Admiral',
#  'Ravenna',
#  'Pioneer Square',
#  'Highland Park',
#  'Pioneer Square',
#  'International District',
#  'Bitter Lake',
#  'Roosevelt',
#  'Holly Park',
#  'Brighton',
#  'First Hill',
#  'Crown Hill',
#  'Stevens',
#  'Columbia City',
#  'Greenwood',
#  'Wallingford',
#  'Broadway',
#  'Stevens',
#  'Mount Baker',
#  'Windermere',
#  'North Queen Anne',
#  'Mid-Beacon Hill',
#  'Central Business District',
#  'Leschi',
#  'North Admiral',
#  'South Delridge',
#  'North Admiral',
#  'First Hill',
#  'North College Park',
#  'Lawton Park',
#  'Central Business District',
#  'Phinney Ridge',
#  'Cedar Park',
#  'Broadview',
#  'Central Business District',
#  'Atlantic',
#  'Belltown',
#  'Columbia City',
#  'Seward Park',
#  'North Admiral',
#  'Bitter Lake',
#  'Yesler Terrace',
#  'Dunlap',
#  'Pioneer Square',
#  'Windermere',
#  'Bitter Lake',
#  'Wallingford',
#  'Cedar Park',
#  'Bryant',
#  'North Admiral',
#  'Pioneer Square',
#  'Columbia City',
#  'Yesler Terrace',
#  'Lower Queen Anne',
#  'Industrial District',
#  'Belltown',
#  'North Beacon Hill',
#  'Mann',
#  'Bitter Lake',
#  'Ravenna',
#  'Pioneer Square',
#  'Bitter Lake',
#  'Pike-Market',
#  'Yesler Terrace',
#  'Lower Queen Anne',
#  'Mount Baker',
#  'First Hill',
#  'Yesler Terrace',
#  'Pioneer Square',
#  'Columbia City',
#  'Belltown',
#  'Belltown',
#  'First Hill',
#  'Belltown',
#  'Crown Hill',
#  'South Delridge',
#  'Mann',
#  'Crown Hill',
#  'East Queen Anne',
#  'Columbia City',
#  'Alki',
#  'Crown Hill',
#  'First Hill',
#  'Victory Heights',
#  'Lower Queen Anne',
#  'Dunlap',
#  'Pioneer Square',
#  'University District',
#  'South Delridge',
#  'Columbia City',
#  'Holly Park',
#  'Lower Queen Anne',
#  'Roosevelt',
#  'Central Business District',
#  'East Queen Anne',
#  'Olympic Hills',
#  'Lower Queen Anne',
#  'Lower Queen Anne',
#  'University District',
#  'Belltown',
#  'Belltown',
#  'Pike-Market',
#  'Fremont',
#  'Broadway',
#  'Yesler Terrace',
#  'Highland Park',
#  'North College Park',
#  'Brighton',
#  'Bryant',
#  'Madrona',
#  'North Queen Anne',
#  'Fauntleroy',
#  'Stevens',
#  'Mann',
#  'Yesler Terrace',
#  'Madrona',
#  'Windermere',
#  'Gatewood',
#  'Broadway',
#  'Wedgwood',
#  'Cedar Park',
#  'Genesee',
#  'East Queen Anne',
#  'Wallingford',
#  'Pioneer Square',
#  'Georgetown',
#  'Pioneer Square',
#  'Montlake',
#  'Phinney Ridge',
#  'Rainier View',
#  'Broadway',
#  'Minor',
#  'Belltown',
#  'Roosevelt',
#  'South Delridge',
#  'Belltown',
#  'South Delridge',
#  'West Woodland',
#  'High Point',
#  'North Beacon Hill',
#  'Bryant',
#  'Harrison/Denny-Blaine',
#  'Pioneer Square',
#  'Pioneer Square',
#  'North Admiral',
#  'Stevens',
#  'Whittier Heights',
#  'Pioneer Square',
#  'North Queen Anne',
#  'Pike-Market',
#  'Genesee',
#  'East Queen Anne',
#  'Rainier View',
#  'Broadway',
#  'Green Lake',
#  'Greenwood',
#  'International District',
#  'Roosevelt',
#  'Broadway',
#  'International District',
#  'Mount Baker',
#  'Bitter Lake',
#  'Loyal Heights',
#  'University District',
#  'Central Business District',
#  'Fremont',
#  'Ravenna',
#  'North Beacon Hill',
#  'North Admiral',
#  'Industrial District',
#  'Pioneer Square',
#  'Columbia City',
#  'Columbia City',
#  'Central Business District',
#  'Pioneer Square',
#  'Laurelhurst',
#  'Central Business District',
#  'Stevens',
#  'Madrona',
#  'International District',
#  'Unknown',
#  'Central Business District',
#  'Windermere',
#  'High Point',
#  'Bryant',
#  'Georgetown',
#  'Minor',
#  'Roxhill',
#  'Briarcliff',
#  'Central Business District',
#  'Interbay',
#  'Seward Park',
#  'South Lake Union',
#  'Atlantic',
#  'Central Business District',
#  'Broadway',
#  'Green Lake',
#  'Phinney Ridge',
#  'Atlantic',
#  'Belltown',
#  'Whittier Heights',
#  'Southeast Magnolia',
#  'Belltown',
#  'Roosevelt',
#  'Lower Queen Anne',
#  'Belltown',
#  'Laurelhurst',
#  'Victory Heights',
#  'Olympic Hills',
#  'Broadway',
#  'Laurelhurst',
#  'Victory Heights',
#  'Belltown',
#  'Greenwood',
#  'Atlantic',
#  'Belltown',
#  'International District',
#  'Genesee',
#  'Leschi',
#  'Central Business District',
#  'Greenwood',
#  'South Lake Union',
#  'South Delridge',
#  'Olympic Hills',
#  'High Point',
#  'Stevens',
#  'Phinney Ridge',
#  'North Queen Anne',
#  'Stevens',
#  'Haller Lake',
#  'Madrona',
#  'University District',
#  'South Park',
#  'Pioneer Square',
#  'Roxhill',
#  'Central Business District',
#  'Belltown',
#  'West Queen Anne',
#  'First Hill',
#  'University District',
#  'Broadview',
#  'Bitter Lake',
#  'Madison Park',
#  'First Hill',
#  'Bitter Lake',
#  'Central Business District',
#  'Bitter Lake',
#  'Pioneer Square',
#  'Fairmount Park',
#  'Pioneer Square',
#  'Mid-Beacon Hill',
#  'Lower Queen Anne',
#  'Crown Hill',
#  'Industrial District',
#  'Bitter Lake',
#  'North Admiral',
#  'Broadway',
#  'East Queen Anne',
#  'Adams',
#  'Broadway',
#  'Dunlap',
#  'First Hill',
#  'Broadway',
#  'Loyal Heights',
#  'North Admiral',
#  'Mid-Beacon Hill',
#  'High Point',
#  'Columbia City',
#  'Roxhill',
#  'Greenwood',
#  'South Park',
#  'North Queen Anne',
#  'Genesee',
#  'Mid-Beacon Hill',
#  'Ravenna',
#  'Cedar Park',
#  'North Admiral',
#  'Maple Leaf',
#  'Broadway',
#  'University District',
#  'Belltown',
#  'Greenwood',
#  'Belltown',
#  'Belltown',
#  'Atlantic',
#  'Belltown',
#  'Central Business District',
#  'Whittier Heights',
#  'Pioneer Square',
#  'North Admiral',
#  'Industrial District',
#  'South Beacon Hill',
#  'Phinney Ridge',
#  'Phinney Ridge',
#  'Mann',
#  'Brighton',
#  'Pioneer Square',
#  'Belltown',
#  'Greenwood',
#  'Stevens',
#  'North Beacon Hill',
#  'Broadway',
#  'North Admiral',
#  'Montlake',
#  'Central Business District',
#  'Minor',
#  'Brighton',
#  'North Admiral',
#  'Olympic Hills',
#  'Gatewood',
#  'Victory Heights',
#  'International District',
#  'North College Park',
#  'Central Business District',
#  'Pioneer Square',
#  'Belltown',
#  'Belltown',
#  'Lawton Park',
#  'Haller Lake',
#  'Stevens',
#  'North Beacon Hill',
#  'Fairmount Park',
#  'Madrona',
#  'South Delridge',
#  'Central Business District',
#  'Seaview',
#  'Belltown',
#  'Crown Hill',
#  'East Queen Anne',
#  'Madison Park',
#  'Rainier View',
#  'Matthews Beach',
#  'Adams',
#  'First Hill',
#  'Arbor Heights',
#  'Pioneer Square',
#  'North Beacon Hill',
#  'Bitter Lake',
#  'High Point',
#  'Pioneer Square',
#  'Central Business District',
#  'Pioneer Square',
#  'Mount Baker',
#  'Dunlap',
#  'South Beacon Hill',
#  'Interbay',
#  'Brighton',
#  'South Delridge',
#  'North Admiral',
#  'Fairmount Park',
#  'Central Business District',
#  'Roosevelt',
#  'North Beach/Blue Ridge',
#  'Broadway',
#  'Broadway',
#  'Fauntleroy',
#  'Seward Park',
#  'East Queen Anne',
#  'Pinehurst',
#  'Broadway',
#  'Adams',
#  'Belltown',
#  'Broadway',
#  'South Beacon Hill',
#  'Haller Lake',
#  'Ravenna',
#  'Bitter Lake',
#  'Eastlake',
#  'Meadowbrook',
#  'Industrial District',
#  'Unknown',
#  'Mid-Beacon Hill',
#  'Roosevelt',
#  'Alki',
#  'Bryant',
#  'Columbia City',
#  'Broadview',
#  'Columbia City',
#  'North Beacon Hill',
#  'Belltown',
#  'Broadway',
#  'Loyal Heights',
#  'South Delridge',
#  'Adams',
#  'Ravenna',
#  'Pioneer Square',
#  'Pike-Market',
#  'Harbor Island',
#  'East Queen Anne',
#  'Belltown',
#  'Loyal Heights',
#  'Crown Hill',
#  'Harbor Island',
#  'Broadway',
#  'North Queen Anne',
#  'Belltown',
#  'Madrona',
#  'Greenwood',
#  'Portage Bay',
#  'Central Business District',
#  'Yesler Terrace',
#  'University District',
#  'Atlantic',
#  'Wallingford',
#  'Fauntleroy',
#  'Minor',
#  'First Hill',
#  'Atlantic',
#  'Fremont',
#  'Genesee',
#  'Broadway',
#  'Industrial District',
#  'Central Business District',
#  'Belltown',
#  'North Queen Anne',
#  'Windermere',
#  'North Queen Anne',
#  'Bitter Lake',
#  'Bitter Lake',
#  'South Delridge',
#  'Pioneer Square',
#  'Madison Park',
#  'Pinehurst',
#  'Olympic Hills',
#  'Fauntleroy',
#  'Cedar Park',
#  'Cedar Park',
#  'South Delridge',
#  'Lower Queen Anne',
#  'Mount Baker',
#  'First Hill',
#  'Victory Heights',
#  'Stevens',
#  'Stevens',
#  'Roosevelt',
#  'Stevens',
#  'South Park',
#  'Wallingford',
#  'Brighton',
#  'Pioneer Square',
#  'Pioneer Square',
#  'Adams',
#  'University District',
#  'Pioneer Square',
#  'Broadway',
#  'North Beach/Blue Ridge',
#  'Broadway',
#  'Laurelhurst',
#  'Pioneer Square',
#  'North Delridge',
#  'Broadview',
#  'South Lake Union',
#  'Alki',
#  'Yesler Terrace',
#  'Yesler Terrace',
#  'Industrial District',
#  'Bitter Lake',
#  'Industrial District',
#  'Stevens',
#  'Pike-Market',
#  'Roosevelt',
#  'Brighton',
#  'University District',
#  'Roxhill',
#  'North Beacon Hill',
#  'Central Business District',
#  'Minor',
#  'Belltown',
#  'Belltown',
#  'Lower Queen Anne',
#  'Belltown',
#  'Pioneer Square',
#  'Wedgwood',
#  'Seward Park',
#  'North Delridge',
#  'Victory Heights',
#  'International District',
#  'Bitter Lake',
#  'Lower Queen Anne',
#  'Broadway',
#  'Ravenna',
#  'Industrial District',
#  'West Queen Anne',
#  'Riverview',
#  'West Woodland',
#  'Dunlap',
#  'Highland Park',
#  'Columbia City',
#  'Belltown',
#  'Westlake',
#  'Central Business District',
#  'Lower Queen Anne',
#  'Broadway',
#  'Yesler Terrace',
#  'University District',
#  'South Lake Union',
#  'Riverview',
#  'South Delridge',
#  'Central Business District',
#  'North College Park',
#  'Interbay',
#  'Stevens',
#  'Central Business District',
#  'Green Lake',
#  'Industrial District',
#  'Bitter Lake',
#  'Rainier Beach',
#  'Victory Heights',
#  'University District',
#  'West Woodland',
#  'Riverview',
#  'University District',
#  'Industrial District',
#  'North Beacon Hill',
#  'North Beacon Hill',
#  'Highland Park',
#  'Belltown',
#  'Dunlap',
#  'Pinehurst',
#  'University District',
#  'University District',
#  'Montlake',
#  'Central Business District',
#  'Central Business District',
#  'Belltown',
#  'Broadway',
#  'Atlantic',
#  'Riverview',
#  'Belltown',
#  'Olympic Hills',
#  'South Beacon Hill',
#  'East Queen Anne',
#  'Rainier View',
#  'Wedgwood',
#  'First Hill',
#  'High Point',
#  'Bryant',
#  'North Beach/Blue Ridge',
#  'Industrial District',
#  'Adams',
#  'Industrial District',
#  'Bitter Lake',
#  'Maple Leaf',
#  'Maple Leaf',
#  'Greenwood',
#  'Central Business District',
#  'Roxhill',
#  'Brighton',
#  'Stevens',
#  'Bitter Lake',
#  'Alki',
#  'Central Business District',
#  'South Lake Union',
#  'Mount Baker',
#  'Green Lake',
#  'Haller Lake',
#  'Stevens',
#  'University District',
#  'Wallingford',
#  'University District',
#  'Eastlake',
#  'North Delridge',
#  'Wedgwood',
#  'Georgetown',
#  'Broadway',
#  'Broadway',
#  'Highland Park',
#  'Lower Queen Anne',
#  'Lower Queen Anne',
#  'Bitter Lake',
#  'Matthews Beach',
#  'Broadway',
#  'Olympic Hills',
#  'Riverview',
#  'Genesee',
#  'Fremont',
#  'Pinehurst',
#  'Olympic Hills',
#  'Pike-Market',
#  'Adams',
#  'Bitter Lake',
#  'University District',
#  'Madison Park',
#  'Fremont',
#  'Pioneer Square',
#  'University District',
#  'Highland Park',
#  'Fremont',
#  'Loyal Heights',
#  'Columbia City',
#  'Sunset Hill',
#  'Bitter Lake',
#  'University District',
#  'University District',
#  'Atlantic',
#  'International District',
#  'Columbia City',
#  'University District',
#  'Crown Hill',
#  'High Point',
#  'South Delridge',
#  'Stevens',
#  'University District',
#  'University District',
#  'Central Business District',
#  'North Beach/Blue Ridge',
#  'Seward Park',
#  'University District',
#  'Lower Queen Anne',
#  'North Beacon Hill',
#  'South Beacon Hill',
#  'Columbia City',
#  'Belltown',
#  'North College Park',
#  'Olympic Hills',
#  'Central Business District',
#  'Central Business District',
#  'University District',
#  'Dunlap',
#  'North College Park',
#  'Belltown',
#  'Lawton Park',
#  'Central Business District',
#  'University District',
#  'Central Business District',
#  'Wallingford',
#  'Ravenna',
#  'Belltown',
#  'Highland Park',
#  'Central Business District',
#  'Broadview',
#  'Central Business District',
#  'Central Business District',
#  'Eastlake',
#  'Riverview',
#  'University District',
#  'Atlantic',
#  'South Beacon Hill',
#  'High Point',
#  'Columbia City',
#  'Pinehurst',
#  'Industrial District',
#  'Pioneer Square',
#  'Mid-Beacon Hill',
#  'Central Business District',
#  'Genesee',
#  'First Hill',
#  'University District',
#  'Mid-Beacon Hill',
#  'Haller Lake',
#  'Pioneer Square',
#  'Broadway',
#  'University District',
#  'Rainier View',
#  'Pioneer Square',
#  'Broadview',
#  'Yesler Terrace',
#  'Belltown',
#  'Belltown',
#  'Georgetown',
#  'North Admiral',
#  'Central Business District',
#  'Brighton',
#  'Riverview',
#  'Madison Park',
#  'Cedar Park',
#  'Harrison/Denny-Blaine',
#  'Victory Heights',
#  'Atlantic',
#  'Highland Park',
#  'Olympic Hills',
#  'South Delridge',
#  'Mid-Beacon Hill',
#  'Industrial District',
#  'Holly Park',
#  'Pioneer Square',
#  'Briarcliff',
#  'Pike-Market',
#  'Bitter Lake',
#  'Whittier Heights',
#  'Columbia City',
#  'South Lake Union',
#  'Broadway',
#  'Wallingford',
#  'Pioneer Square',
#  'Pioneer Square',
#  'Haller Lake',
#  'North Admiral',
#  'Greenwood',
#  'Broadway',
#  'Haller Lake',
#  'Georgetown',
#  'Brighton',
#  'Maple Leaf',
#  'Phinney Ridge',
#  'International District',
#  'Broadway',
#  'Belltown',
#  'Greenwood',
#  'Green Lake',
#  'Georgetown',
#  'Belltown',
#  'Westlake',
#  'Holly Park',
#  'Minor',
#  'Central Business District',
#  'Columbia City',
#  'Pike-Market',
#  'Brighton',
#  'Belltown',
#  'Belltown',
#  'Lower Queen Anne',
#  'North Queen Anne',
#  'Pioneer Square',
#  'Mid-Beacon Hill',
#  'Olympic Hills',
#  'North Admiral',
#  'Pinehurst',
#  'Madrona',
#  'Adams',
#  'Stevens',
#  'Mid-Beacon Hill',
#  'Westlake',
#  'Stevens',
#  'Lower Queen Anne',
#  'University District',
#  'University District',
#  'First Hill',
#  'Atlantic',
#  'Central Business District',
#  'Bryant',
#  'Broadway',
#  'Belltown',
#  'Broadway',
#  'Central Business District',
#  'Broadway',
#  'Seward Park',
#  'University District',
#  'Belltown',
#  'South Delridge',
#  'Minor',
#  'First Hill',
#  'Westlake',
#  'University District',
#  'Whittier Heights',
#  ...]

# %%
df['neighborhood'] = Labels

# %%
zone1 = ['Sunset Hill', 'Crown Hill', 'Greenwood', 'North College Park',
         'North Beach/Blue Ridge', 'Broadview', 'Bitter Lake',
         'Haller Lake', 'Loyal Heights', 'Adams', 'Whittier Heights',
         'West Woodland', 'Phinney Ridge', 'Wallingford', 'Fremont',
         'Green Lake']

zone2 = ['Pinehurst', 'Maple Leaf', 'Wedgwood', 'Matthews Beach',
         'Meadowbrook', 'Olympic Hills', 'Cedar Park', 'Victory Heights',
         'View Ridge', 'Ravenna', 'Sand Point', 'Bryant', 'Windermere',
         'Laurelhurst', 'Roosevelt', 'University District']

zone3 = ['West Queen Anne', 'North Queen Anne', 'Eastlake', 
         'South Lake Union', 'Lawton Park', 'Briarcliff', 
         'Southeast Magnolia', 'Interbay']

zone4 = ['Montlake', 'Portage Bay', 'Madison Park', 'Broadway',
         'Stevens', 'Leschi', 'Madrona', 'Harrison/Denny-Blaine',
         'Minor', 'Mann', 'Atlantic', 'First Hill', 'Yesler Terrace']

zone5 = ['Pike-Market', 'International District', 
         'Central Business District', 'Pioneer Square']

zone6 = ['Belltown', 'East Queen Anne', 'Lower Queen Anne', 'Westlake']

zone7 = ['Alki', 'North Admiral', 'Fairmount Park', 'Genesee',
         'Fauntleroy', 'North Delridge', 'Riverview', 'High Point',
         'South Delridge', 'Roxhill', 'Highland Park', 'Harbor Island',
         'South Park', 'Seaview', 'Gatewood', 'Arbor Heights']

zone8 = ['North Beacon Hill', 'Mid-Beacon Hill', 'South Beacon Hill',
         'Brighton', 'Dunlap', 'Rainier Beach', 'Rainier View',
         'Mount Baker', 'Columbia City', 'Seward Park', 'Georgetown',
         'Holly Park', 'Industrial District']

# %%
df['zone1'] = df.neighborhood.isin(zone1).astype(int)
df['zone2'] = df.neighborhood.isin(zone2).astype(int)
df['zone3'] = df.neighborhood.isin(zone3).astype(int)
df['zone4'] = df.neighborhood.isin(zone4).astype(int)
df['zone5'] = df.neighborhood.isin(zone5).astype(int)
df['zone6'] = df.neighborhood.isin(zone6).astype(int)
df['zone7'] = df.neighborhood.isin(zone7).astype(int)
df['zone8'] = df.neighborhood.isin(zone7).astype(int)

# %%
df.head().T

# %%
df.to_csv("../data/features_seattle_911_no_dup_hoods.csv")
